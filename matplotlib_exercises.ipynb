# %% [markdown]
# ## Matplotlib Exercises

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
from random import randint
import random

# %% [markdown]
# ### 1. Use matplotlib to plot the following equation:
# ## y=x^2−x+2
# ### You'll need to write the code that generates the x and y points.
# ### Add an anotation for the point 0, 0, the origin.

# %%
x = np.arange(50)
y = (x**2)-x+2

# %%
plt.plot(x,y, c='red')

plt.annotate('Origin', xy=(0,0), xytext=(-2,250),arrowprops={'facecolor': 'blue'})
# Out:
# Text(-2, 250, 'Origin')

# %% [markdown]
# ### 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
# - y=√x
# - y=x3
# - y=2x
# - y=1/(x+1)
# ### You can use functions from the math module to help implement some of the equations above.

# %%
x=np.arange(150)
y=x**.5
plt.plot(x,y, c='red')
plt.title('Square Roots from 0 to 150')
plt.xlabel('Numbers to be square rooted')
plt.ylabel('Square root of x')
# Out:
# Text(0, 0.5, 'Square root of x')

# %%
x=np.arange(-15,15)
y=x**3
plt.plot(x,y, c ='green')
plt.title('Range from 0 to 50 Cubed')
plt.xlabel('Non-suspecting numbers')
plt.ylabel('Cubed result')
# Out:
# Text(0, 0.5, 'Cubed result')

# %%
x=np.arange(10)
y=2**x
plt.plot(x,y, c ='cyan')
plt.title('2 to the power of X')
plt.xlabel('Extent of Exponentiation')
plt.ylabel('Result of incremented values to exponent of x')
# Out:
# Text(0, 0.5, 'Result of incremented values to exponent of x')

# %%
x=np.arange(10)
y=1/(x+1)
plt.plot(x,y, c ='purple')
plt.title('Ever Decreasing Fractions')
plt.xlabel('Denominator')
plt.ylabel('Fraction dictated')
# Out:
# Text(0, 0.5, 'Fraction dictated')

# %% [markdown]
# ### 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
x=np.arange(150)
y=x**.5
plt.subplot(2,2,1)
plt.plot(x,y, c='red')
plt.title('Square Roots from 0 to 150')
plt.xlabel('Numbers to be square rooted')
plt.ylabel('Square root of x')


x=np.arange(-15,15)
y=x**3
plt.subplot(2,2,2)
plt.plot(x,y, c ='green')
plt.title('Range from 0 to 50 Cubed')
plt.xlabel('Non-suspecting numbers')
plt.ylabel('Cubed result')

x=np.arange(10)
y=2**x
plt.subplot(2,2,3)
plt.plot(x,y, c ='cyan')
plt.title('2 to the power of X')
plt.xlabel('Extent of Exponentiation')
plt.ylabel('Exponentiation of 2')

x=np.arange(10)
y=1/(x+1)
plt.subplot(2,2,4)
plt.plot(x,y, c ='purple')
plt.title('Ever Decreasing Fractions')
plt.xlabel('Denominator')
plt.ylabel('Fraction dictated')

plt.suptitle('Combined figures')
plt.subplots_adjust(wspace=.75, hspace=.75)

# %% [markdown]
# ### 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
x = np.arange(0,10)
root_of_x = x**.5
x_cubed = x**3
two_to_x = 2**x
fraction_of_x = 1/(x+1)

plt.figure(figsize=(10, 8))

plt.plot(x, root_of_x, c='blue', label='$√x$')
plt.plot(x, x_cubed, c='red', label='$x^3$')
plt.plot(x, two_to_x, c='green', label='$2^x$')
plt.plot(x, fraction_of_x, c='orange', label='$1/(x+1)$')

plt.xlim(0,8)
plt.ylim(0,20)
plt.grid(ls='-')

plt.legend(loc='upper left')
plt.title('Equations of X')
plt.xlabel('Elements')
plt.ylabel('Operations')
# Out:
# Text(0, 0.5, 'Operations')

# %% [markdown]
# ### 5. Make a new Jupyter notebook named big_o_notation.ipynb
#
# - Title your chart "Big O Notation"
# - Label your x axis "Elements"
# - Label your y axis "Operations"
# - Label your curves or make a legend for the curves
# - Use LaTex notation where possible
# ### Curves to graph
# - y=0n+1 and label the curve "O(1)"
# - y=log(n) and label the curve "O(log n)"
# - y=n and label the curve "O(n)"
# - y=n∗log(n) and label it "O(n log n)"
# - y=n^2 and label it "O(n^2)"
# - y=2^n and label it "O(2^n)"
# - y=n! and label it "O(n!)"
# - y=n^n and label it "O(n^n)"

# %%
done!

# %% [markdown]
# ### 6. Bonus: Write the code necessary to write your name on a chart. Use box letters.

# %%
j1=[.5,1]
e1=[0,0]

j2=[1,1,1]
e2=[0,1,1.75]

j3=[0,.5]
e3=[1,0]


a1=[1.5,2]
e4=[0,1.75]

a2=[2,2.5]
e5=[1.75,0]

a3=[1.75,2.25]
e6=[1,1]

y1=[3,3.5]
e7=[1.75,.875]

y2=[3.5,4]
e8=[.875,1.75]

y3=[3.5,3.5]
e9=[0,.875]

#J
plt.plot(j1,e1, linewidth=5, c='red')
plt.plot(j2,e2, linewidth=5, c='red')
plt.plot(j3,e3, linewidth=5, c='red')
#A
plt.plot(a1,e4, linewidth=5, c='blue')
plt.plot(a2,e5, linewidth=5, c='blue')
plt.plot(a3,e6, linewidth=5, c='blue')
#Y
plt.plot(y1,e7, linewidth=5, c='maroon')
plt.plot(y2,e8, linewidth=5, c='maroon')
plt.plot(y3,e9, linewidth=5, c='maroon')

# %% [markdown]
# ### 7. Bonus: use curves for letters in your name that have curves in them.
