# %%
import numpy as np
import pandas as pd
from pydataset import data
np.random.seed(117)

# %% [markdown]
# ## 1. Copy the code from the lesson to create a dataframe full of student grades.

# %%
students = ['Sally',
            'Jane',
            'Suzie',
            'Billy',
            'Ada',
            'John',
            'Thomas',
            'Marie',
            'Albert',
            'Richard',
            'Isaac',
            'Alan']

# %%
pd.Series(students)
# Out:
# 0       Sally
# 1        Jane
# 2       Suzie
# 3       Billy
# 4         Ada
# 5        John
# 6      Thomas
# 7       Marie
# 8      Albert
# 9     Richard
# 10      Isaac
# 11       Alan
# dtype: object

# %%
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

# %%
df_dict = {'name':students,
           'math': math_grades,
           'english': english_grades,
           'reading':reading_grades}

# %%
df = pd.DataFrame(df_dict)

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    76       71       79
# 1      Jane    77       98       97
# 2     Suzie    83       62       84
# 3     Billy    79       82       65
# 4       Ada    93       82       64
# 5      John    97       93       80
# 6    Thomas    77       74       94
# 7     Marie    71       76       91
# 8    Albert    94       91       74
# 9   Richard    87       72       91
# 10    Isaac    62       67       68
# 11     Alan    86       97       85

# %% [markdown]
# ### a. Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
df['passing_english'] = df.english >= 70

# %%
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    76       71       79             True
# 1      Jane    77       98       97             True
# 2     Suzie    83       62       84            False
# 3     Billy    79       82       65             True
# 4       Ada    93       82       64             True
# 5      John    97       93       80             True
# 6    Thomas    77       74       94             True
# 7     Marie    71       76       91             True
# 8    Albert    94       91       74             True
# 9   Richard    87       72       91             True
# 10    Isaac    62       67       68            False
# 11     Alan    86       97       85             True

# %% [markdown]
# ### b. Sort the english grades by the passing_english column. How are duplicates handled?

# %%
df.sort_values(by='passing_english')
# Out:
#        name  math  english  reading  passing_english
# 2     Suzie    83       62       84            False
# 10    Isaac    62       67       68            False
# 0     Sally    76       71       79             True
# 1      Jane    77       98       97             True
# 3     Billy    79       82       65             True
# 4       Ada    93       82       64             True
# 5      John    97       93       80             True
# 6    Thomas    77       74       94             True
# 7     Marie    71       76       91             True
# 8    Albert    94       91       74             True
# 9   Richard    87       72       91             True
# 11     Alan    86       97       85             True

# %% [markdown]
# ### c. Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(by='name').sort_values(by='passing_english')
# Out:
#        name  math  english  reading  passing_english
# 10    Isaac    62       67       68            False
# 2     Suzie    83       62       84            False
# 4       Ada    93       82       64             True
# 11     Alan    86       97       85             True
# 8    Albert    94       91       74             True
# 3     Billy    79       82       65             True
# 1      Jane    77       98       97             True
# 5      John    97       93       80             True
# 7     Marie    71       76       91             True
# 9   Richard    87       72       91             True
# 0     Sally    76       71       79             True
# 6    Thomas    77       74       94             True

# %% [markdown]
# ### d. Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.sort_values(by='passing_english').sort_values(by='english')
# Out:
#        name  math  english  reading  passing_english
# 2     Suzie    83       62       84            False
# 10    Isaac    62       67       68            False
# 0     Sally    76       71       79             True
# 9   Richard    87       72       91             True
# 6    Thomas    77       74       94             True
# 7     Marie    71       76       91             True
# 3     Billy    79       82       65             True
# 4       Ada    93       82       64             True
# 8    Albert    94       91       74             True
# 5      John    97       93       80             True
# 11     Alan    86       97       85             True
# 1      Jane    77       98       97             True

# %% [markdown]
# ### e. Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df['overall grade'] = (df.english + df.math + df.reading) / 3

# %%
df
# Out:
#        name  math  english  reading  passing_english  overall grade
# 0     Sally    76       71       79             True      75.333333
# 1      Jane    77       98       97             True      90.666667
# 2     Suzie    83       62       84            False      76.333333
# 3     Billy    79       82       65             True      75.333333
# 4       Ada    93       82       64             True      79.666667
# 5      John    97       93       80             True      90.000000
# 6    Thomas    77       74       94             True      81.666667
# 7     Marie    71       76       91             True      79.333333
# 8    Albert    94       91       74             True      86.333333
# 9   Richard    87       72       91             True      83.333333
# 10    Isaac    62       67       68            False      65.666667
# 11     Alan    86       97       85             True      89.333333

# %% [markdown]
# ## 2. Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
mpg = data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# ### a. How many rows and columns are there?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# ### b. What are the data types of each column?

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %% [markdown]
# ### c. Summarize the dataframe with .info and .describe

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# ### d. Rename the cty column to city.

# %%
mpg = mpg.rename(columns={'cty': 'city'})

# %% [markdown]
# ### e. Rename the hwy column to highway.

# %%
mpg = mpg.rename(columns={'hwy': 'highway'})

# %% [markdown]
# ### f. Do any cars have better city mileage than highway mileage?

# %%
better_city_milage = (mpg.city > mpg.highway).sum()

# %%
better_city_milage
# Out:
# 0

# %% [markdown]
# No

# %% [markdown]
# ### g. Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = (mpg.highway - mpg.city)

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference
# ...

# %% [markdown]
# ### h. Which car (or cars) has the highest mileage difference?

# %%
mpg.sort_values(by='mileage_difference', ascending = False).head(2)
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
#
#     fl       class  mileage_difference
# 107  c  subcompact                  12
# 223  d  subcompact                  12

# %% [markdown]
# Both the 2008 Honda Civic and the 1999 Volkswagen New Beetle have the highest mileage differance at 12 miles.

# %% [markdown]
# ### i. Which compact class car has the lowest highway mileage? The best?

# %%
mpg.sort_values('highway', ascending=False)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 222   volkswagen           new beetle    1.9  1999    4  manual(m5)   f    35
# 213   volkswagen                jetta    1.9  1999    4  manual(m5)   f    33
# 223   volkswagen           new beetle    1.9  1999    4    auto(l4)   f    29
# 197       toyota              corolla    1.8  2008    4  manual(m5)   f    28
# 106        honda                civic    1.8  2008    4    auto(l5)   f    25
# ..           ...                  ...    ...   ...  ...         ...  ..   ...
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4     9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
#
# ...

# %%
max_hwy_compact = mpg[mpg['class'] == 'compact'].describe()['highway']['max']

# %%
min_hwy_compact = mpg[mpg['class'] == 'compact'].describe()['highway']['min']

# %%
mpg[(mpg.highway == max_hwy_compact) | (mpg.highway == min_hwy_compact)]
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  city  \
# 18          audi    a6 quattro    4.2  2008    8    auto(s6)   4    16
# 25     chevrolet      corvette    5.7  1999    8    auto(l4)   r    15
# 47         dodge   caravan 2wd    3.8  2008    6    auto(l6)   f    16
# 48         dodge   caravan 2wd    4.0  2008    6    auto(l6)   f    16
# 97          ford       mustang    4.6  2008    8  manual(m5)   r    15
# 165       subaru  forester awd    2.5  2008    4    auto(l4)   4    18
# 213   volkswagen         jetta    1.9  1999    4  manual(m5)   f    33
# 220   volkswagen         jetta    2.8  1999    6    auto(l4)   f    16
# 222   volkswagen    new beetle    1.9  1999    4  manual(m5)   f    35
#
#      highway fl       class  mileage_difference
# 18        23  p     midsize                   7
# 25        23  p     2seater                   8
# 47        23  r     minivan                   7
# 48        23  r     minivan                   7
# ...

# %% [markdown]
# 1999 Volkswagen Jetta with manual transmission and 4 cylinders has the best highway milage at 44. Oddly enough, the 1999 Volkswagen Jetta but with auto transmission and 6 cylinders also had the worst(lowest) highway milage at 23.

# %% [markdown]
# ### j. Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = ((mpg.highway + mpg.city) / 2)

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# ### k. Which dodge car has the best average mileage? The worst?

# %%
max_avg_mileage_dodge = mpg[mpg['manufacturer'] == 'dodge'].describe()['average_mileage']['max']

# %%
min_avg_mileage_dodge = mpg[mpg['manufacturer'] == 'dodge'].describe()['average_mileage']['min']

# %%
mpg[(mpg.average_mileage == max_avg_mileage_dodge) | (mpg.average_mileage == min_avg_mileage_dodge)]
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 5           audi                   a4    2.8  1999    6    auto(l5)   f    16
# 13          audi           a4 quattro    2.8  1999    6  manual(m5)   4    17
# 14          audi           a4 quattro    3.1  2008    6    auto(s6)   4    17
# 17          audi           a6 quattro    3.1  2008    6    auto(s6)   4    17
# 24     chevrolet             corvette    5.7  1999    8  manual(m6)   r    16
# 26     chevrolet             corvette    6.2  2008    8  manual(m6)   r    16
# 38         dodge          caravan 2wd    2.4  1999    4    auto(l3)   f    18
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# ...

# %% [markdown]
# The 1999 Dodge Caravan 2WD with 4 cyclinders and auto transmission has the highest average mileage at 21. The 2008 Dodge Ram 1500 pickup 4wd has the worst average milage at 10.5.

# %% [markdown]
# ## 3. Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
data('Mammals')
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
mammals = data('Mammals')

# %% [markdown]
# ### a. How many rows and columns are there?

# %%
mammals.shape
# Out:
# (107, 4)

# %% [markdown]
# 107 rows, 4 columns

# %% [markdown]
# ### b. What are the data types?

# %%
mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %% [markdown]
# ### c. Summarize the dataframe with .info and .describe

# %%
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %% [markdown]
# ### d. What is the the weight of the fastest animal?

# %%
mammals.sort_values(by='speed',ascending = False).head(1)
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %% [markdown]
# 55 kg

# %% [markdown]
# ### e. What is the overal percentage of specials?

# %%
spec_mamm = mammals['specials'].value_counts()[True]

# %%
spec_mamm
# Out:
# 10

# %%
tot_mamm = (mammals['specials'].value_counts()[True]) + mammals['specials'].value_counts()[False]

# %%
per_spec = spec_mamm / tot_mamm

# %%
#this is done
print(f'The overall percentage of specials is {round(per_spec,4) * 100}%')
# Out:
# The overall percentage of specials is 9.35%

# %%
# ignore this
#just trying to do eveything in one line
#print(f' The overall percentage of specials is {round(mammals['specials'].value_counts()[True] / (mammals['specials'].value_counts()[True]) + mammals['specials'].value_counts()[False],3) * 100}%')

# %% [markdown]
# ### f. How many animals are hoppers that are above the median speed? What percentage is this?

# %% [markdown]
# 7 animals, 6.54%

# %%
mammals['speed'].describe()
# Out:
# count    107.000000
# mean      46.208411
# std       26.716778
# min        1.600000
# 25%       22.500000
# 50%       48.000000
# 75%       65.000000
# max      110.000000
# Name: speed, dtype: float64

# %%
med_speed = mammals['speed'].describe()['50%']

# %%
med_speed
# Out:
# 48.0

# %%
hopp_mamm = mammals['hoppers'].value_counts()[True]

# %%
mammals[(mammals['speed'] > med_speed) & (mammals['hoppers'])]
# Out:
#      weight  speed  hoppers  specials
# 96      4.6   64.0     True     False
# 97      4.4   72.0     True     False
# 98      4.0   72.0     True     False
# 99      3.5   56.0     True     False
# 100     2.0   64.0     True     False
# 101     1.9   56.0     True     False
# 102     1.5   50.0     True     False

# %%
num_hop_above_med = mammals[(mammals['speed'] > med_speed) & (mammals['hoppers'])].count()['hoppers']

# %%
num_hop_above_med
# Out:
# 7

# %%
percent_of_hop_above_med = num_hop_above_med / tot_mamm

# %%
print(f'The overall percentage of hoppers with a speed above the median is {round(percent_of_hop_above_med,4) * 100}%')
# Out:
# The overall percentage of hoppers with a speed above the median is 6.54%
